# %%
# !pip install simplified_scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simplified_scrapy
#   Downloading simplified_scrapy-1.5.164-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: simplified_scrapy
# Successfully installed simplified_scrapy-1.5.164

# %%
import simplified_scrapy

# %%
import requests
from simplified_scrapy.simplified_doc import SimplifiedDoc
import pandas as pd

data_info = []

def data_select(url):

  source = requests.get(url).text
  doc = SimplifiedDoc(source)
  infos = doc.getElements('div', attr='class', value='favorite dui-menu-item')

  for info in infos:
    if info:
        p_url = info['data-item-url']
        product = info['data-item-name']
        price = info['data-price']
        score  = info['data-review-avg']
        data_info.append([p_url, product, price, score])

data_select('https://search.rakuten.co.jp/search/mall/air+purifier/')
data_select('https://search.rakuten.co.jp/search/mall/air+purifier/?p=2')

df = pd.DataFrame(data_info)
df.columns = ['url', 'description', 'price', 'score']
df.head(20)
# Out:
#                                                   url  \
# 0   https://grp07.ias.rakuten.co.jp/redirect_rpp/?...
# 1   https://grp07.ias.rakuten.co.jp/redirect_rpp/?...
# 2   https://grp07.ias.rakuten.co.jp/redirect_rpp/?...
# 3   https://grp07.ias.rakuten.co.jp/redirect_rpp/?...
# 4   https://item.rakuten.co.jp/xiaomiofficial/0001...
# 5   https://item.rakuten.co.jp/roomy/ecl14oct28e01...
# 6   https://item.rakuten.co.jp/xiaomiofficial/0001...
# 7   https://item.rakuten.co.jp/xiaomiauthorizedsto...
# 8   https://item.rakuten.co.jp/donum-select/xiaomi...
# 9   https://item.rakuten.co.jp/plywood/08637004/?v...
# 10  https://item.rakuten.co.jp/r-kojima/7611408027...
# 11  https://item.rakuten.co.jp/boutiquedebonheur/b...
# 12  https://item.rakuten.co.jp/citron-g/z204169047...
# 13  https://item.rakuten.co.jp/plywoodfurniture/08...
# 14  https://item.rakuten.co.jp/panpan/110075/?vari...
# 15  https://item.rakuten.co.jp/stab-blue/6274/?var...
# 16  https://item.rakuten.co.jp/importshopaqua/xqh-...
# 17  https://item.rakuten.co.jp/roomy/pmz18dec03h05...
# 18  https://item.rakuten.co.jp/plywoodzakka/08637001/
# 19       https://item.rakuten.co.jp/plywood/08637001/
#
#                                           description   price score
# 0   IMUNSEN portable Air Purifier M-003 送料無料 空気清浄機...    9900     5
# 1   IMUNSEN portable Air Purifier M-003 送料無料 空気清浄機...   19577     0
# 2   IMUNSEN portable Air Purifier M-003 送料無料 空気清浄機...   72131     0
# 3   正規品 空気清浄機 30畳 Googleアシスタント アレクサー対応 スマホ連動可 花粉症 ...   18500     0
# 4   Xiaomi Mi 空気清浄機 3H Mi Air Purifier 3H 30畳まで対応 ...   19900  4.48
# 5   【特典付き】cado 空気清浄機 LEAF720 AP-C720 カドー正規販売店 リーフ7...  139700  4.82
# 6   Xiaomi 空気清浄機 専用 フィルター Mi Air Purifier HEPA Fil...    3998  4.44
# 7   Xiaomi Mi 空気清浄機 3H Mi Air Purifier 30畳 アプリ操作 静...   19900     5
# 8   Xiaomi互換品 空気清浄機 専用 フィルター Mi Air Purifier HEPA ...    3480   4.5
# 9   プラスマイナスゼロ プラマイゼロ【あす楽14時まで】±0 Air Purifierプラスマイ...    5500  4.29
# 10  ボネコ 空気清浄機 BONECO P230 AIR PURIFIER ホワイト ［適用畳数：...   21800     0
# 11  誰でも使えるクーポン対象 30gと軽量で持ち運びに便利なペンダント型ポータブル空気清浄機 マ...    2739  4.42
# 12  送料無料 空気清浄機 エアフィルター プラスマイナスゼロ ±0 Air Purifier ホ...   22000     5
# 13  プラスマイナスゼロ 空気清浄機 【あす楽14時まで】【送料無料】 特典付き！ ±0 Air ...   22000     4
# 14              Xiaomi 空気清浄機 Mi Air Purifier 3H セール!!   13980     0
# 15  Mini Air Purifier ミニ エアー ピュリファイヤー 空気清浄機 マイナスイオ...    5280     0
# 16  空気清浄機 【温湿時計+クロス2枚の特典】 ±0 空気清浄機 X020 プラスマイナスゼロ ...   22000  4.51
# 17  プラスマイナスゼロ 交換用フィルター 交換 フィルターC030 XQH-C030 XQC-C...    8800     0
# 18  プラスマイナスゼロ 空気清浄機 【あす楽14時まで】【送料無料】 特典付！ ±0 Air P...   22000     5
# 19  プラスマイナスゼロ 空気清浄機【あす楽14時まで】【送料無料】特典付き！±0 Air Pur...   22000  4.31

# %%
df.index
# Out:
# RangeIndex(start=0, stop=98, step=1)

# %%
df.tail()
# Out:
#                                                   url  \
# 93  https://item.rakuten.co.jp/mmon814/10039610/?v...
# 94  https://item.rakuten.co.jp/flaner/10003555/?va...
# 95  https://item.rakuten.co.jp/roomy-garden/ecl22m...
# 96    https://item.rakuten.co.jp/auc-rodeo/5910-5911/
# 97  https://item.rakuten.co.jp/abc-tuhan/sdd201800...
#
#                                           description  price score
# 93  車用空気清浄機 PHLIPS Go Pure Car air purifier GPC10MXX1  15535     0
# 94  ±0 空気清浄機 交換用フィルター XQC−X020 フィルター／プラスマイナスゼロ（KAK...   5500     4
# 95  cado カドー 空気清浄機 LEAF250 正規販売店 21畳 AP-B250 リーフ25...  30420     0
# 96  IonicBreeze イオニックブリーズ GRANDE グランデ 空気清浄機 フィルター交...  26800     0
# 97  WIFI 空気清浄機 アレクサ対応 空気清浄機 花粉 21畳 コンパクト タバコ ほこり 除...  22800     0

# %%
df.to_csv('rekuten1007.csv',  encoding='utf-16')

# %%
import requests
from simplified_scrapy.simplified_doc import SimplifiedDoc
import pandas as pd

data_info = []

def data_select(url):

  source = requests.get(url).text
  doc = SimplifiedDoc(source)
  infos = doc.getElements('a', attr='class', value='itemname')

  for info in infos:
    if info:
        p_href = info['href']
        p_html = info['html']
        data_info.append([p_href, p_html])

data_select('https://www.gmarket.co.kr/n/best')

df = pd.DataFrame(data_info)
df.columns = ['url', 'description']
# df.head(20)
df.to_excel('gmarket.xlsx',  encoding='utf-16')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
